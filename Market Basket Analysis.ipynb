# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
retail = pd.read_excel('/content/drive/My Drive/portofolio/Online Retail.xlsx')

# %%
retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
retail.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
retail.dropna(axis=0, subset=['CustomerID','Description'], inplace=True)
retail['InvoiceNo'] = retail['InvoiceNo'].astype('str') 
 
retail.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
retail.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
print('jumlah data duplikat')
print(retail.duplicated().sum())

print('jumlah setelah dihapus')
retail.drop_duplicates(inplace=True)
print(retail.duplicated().sum())
# Out:
# jumlah data duplikat
# 5225
# jumlah setelah dihapus
# 0

# %%
retail_plus = retail[retail['Quantity']>=0]
retail_plus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392732 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    392732 non-null  object
#  1   StockCode    392732 non-null  object
#  2   Description  392732 non-null  object
#  3   Quantity     392732 non-null  int64
#  4   InvoiceDate  392732 non-null  datetime64[ns]
#  5   UnitPrice    392732 non-null  float64
#  6   CustomerID   392732 non-null  float64
#  7   Country      392732 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.0+ MB

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 401604 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    401604 non-null  object
#  1   StockCode    401604 non-null  object
#  2   Description  401604 non-null  object
#  3   Quantity     401604 non-null  int64
#  4   InvoiceDate  401604 non-null  datetime64[ns]
#  5   UnitPrice    401604 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      401604 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.6+ MB

# %%
retail.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
retail['Country'].value_counts()
# Out:
# United Kingdom          356728
# Germany                   9480
# France                    8475
# EIRE                      7475
# Spain                     2528
# Netherlands               2371
# Belgium                   2069
# Switzerland               1877
# Portugal                  1471
# Australia                 1258
# Norway                    1086
# Italy                      803
# Channel Islands            757
# Finland                    695
# Cyprus                     611
# Sweden                     461
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# USA                        291
# Israel                     247
# Unspecified                241
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# ...

# %%
mybasket = (retail[retail['Country'] =="Spain"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))
mybasket.head()
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536944                                  0.0                       0.0
# 538095                                  0.0                       0.0
# 538525                                  0.0                       0.0
# 539351                                  0.0                       0.0
# 540469                                  0.0                       0.0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# 536944                                    0.0                      0.0
# 538095                                    0.0                      0.0
# 538525                                    0.0                      0.0
# 539351                                    0.0                      0.0
# 540469                                    8.0                      0.0
#
# Description  10 COLOUR SPACEBOY PEN  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# ...

# %%
def my_encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

my_basket_sets = mybasket.applymap(my_encode_units)
my_basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %%
my_frequent_itemsets = apriori(my_basket_sets, min_support=0.03, 
                               use_colnames=True).sort_values('support', ascending=False)
my_rules = association_rules(my_frequent_itemsets, metric="lift", min_threshold=1)

# %%
my_rules.head()
# Out:
#                          antecedents                      consequents  \
# 0           (6 RIBBONS RUSTIC CHARM)  (ASSORTED COLOUR BIRD ORNAMENT)
# 1    (ASSORTED COLOUR BIRD ORNAMENT)         (6 RIBBONS RUSTIC CHARM)
# 2        (POPPY'S PLAYHOUSE KITCHEN)     (POPPY'S PLAYHOUSE BEDROOM )
# 3       (POPPY'S PLAYHOUSE BEDROOM )      (POPPY'S PLAYHOUSE KITCHEN)
# 4  (PACK OF 72 RETROSPOT CAKE CASES)  (ASSORTED COLOUR BIRD ORNAMENT)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.142857            0.114286  0.085714    0.600000   5.250000
# 1            0.114286            0.142857  0.085714    0.750000   5.250000
# 2            0.066667            0.076190  0.066667    1.000000  13.125000
# 3            0.076190            0.066667  0.066667    0.875000  13.125000
# 4            0.104762            0.114286  0.057143    0.545455   4.772727
#
#    leverage  conviction
# 0  0.069388    2.214286
# 1  0.069388    3.428571
# ...
